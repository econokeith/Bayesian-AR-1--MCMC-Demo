# %% [markdown]
# # Bayesian AR(1) MCMC Demo
# ## For New School Economics Bayesian Time Series Reading Group

# %% [markdown]
# This demo estimates a simple simulated AR(1) process using MCMC under the assumption of reference prior, which is not conjugate to the AR parameter, $\phi$. The sampler uses a Gibbs step when sampling the marginal distribution of the variance, $\sigma^2$, and a standard MCMC rejection step when sampling $\phi$.

# %% [markdown]
# #### setup

# %%
from __future__ import division
import numpy as np

import pandas as pd
import scipy as sp
import numpy.random as npr
import scipy.stats as sps
from numpy import array
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from scipy import stats

#use seaborn plotting style defaults
import seaborn as sns; sns.set()

import copy
# %matplotlib inline

import numpy.linalg as la

print sp.__version__

import os
os.getcwd()

from datetime import datetime
# Out:
# 0.18.1

# %% [markdown]
# Import functions from seperate file

# %%
# %run bar1_funs.py

# %% [markdown]
# ## Unconditional AR(1) Estimation with Reference Prior

# %% [markdown]
# The AR(1) process is:

# %% [markdown]
# \begin{equation*}
# y_{t+1}= \phi y_{t}+\epsilon_{t+1}\\
# \text{where $\epsilon$ ~ Normal(0, $\sigma^2$)}
# \end{equation*}

# %% [markdown]
# We assume that

# %% [markdown]
# Make AR(1) with $\phi = .6 $ and $\sigma^2 = 1 $

# %%
phi_real=.5
sig_real = .1
ar_data = make_test_arma(phi0,sig=sig_real, N= 1000)

# %%
plt.figure(figsize=(12,4))
plt.plot(ar_data);
plt.title('Simulated AR Process');

# %%
phi1 = .2
phi2 = .9

q1 = q_star_ar1_phi(ar_data, phi1)
q2 = q_star_ar1_phi(ar_data, phi2)

x = np.linspace(0.007, .023, 1000)

rv = stats.invgamma(len(ar_data)/2, scale=q1/2)
rv2 =  stats.invgamma(len(ar_data)/2, scale=q2/2)

plt.figure(figsize=(12,4))
plt.plot(x**.5, rv.pdf(x), label=phi1)
plt.plot(x**.5, rv2.pdf(x), label=phi2)
plt.legend(loc='best')
plt.title('Inverse Gamma Distribution For phi0={0} (B) / {1} (G)'.format(phi1, phi2));

# %% [markdown]
# The above chart shows the relationship between $\phi$ and $\sigma^2$.

# %% [markdown]
# ### Gibbs/MCMC

# %%
# %%time 

# set initial parameters
data = ar_data
phi0 = .01
v0=1
iterations = 10000

## in practice pick c to allow for an acceptance rate between 25 and, 40%
c = .7
# set up data to be collected
v_list = np.empty(iterations)
phi_list = np.empty(iterations)
r_list = np.empty(iterations)
v_list[0] = v0
phi_list[0] = phi0

n = ar_data.shape[0]

rejected = 0
rejected_oob = 0

qstar= calc_q_star(data, phi0)

for i in xrange(1, iterations):

    # Draw v from inverse gamma distribution v ~ IG(n/2 , Q*(phi)/2)
    # This is a Gibbs Step
    
    phi=phi_list[i-1]
    
    v = stats.invgamma.rvs(n/2, scale = qstar/2)
    v_list[i] = v
    
    # draw phi from jump distribution with phi* ~ N(phi[-1], cv)
    # metropolis step
    phi_new = np.random.randn()* np.sqrt(c * v) + phi
    
    # reject if phi is drawn such that abs(phi) > 1
    # if this isn't there the algo won't run because it will move into the complex space
    # which I haven't accounted for
    if -1 <= phi_new <= 1:

        
        # calculate r as ratio of likelihoods for new and old phi
        # must do done in log form to avoid underflow problems. 
        
        loglike0 = .5*np.log(1-phi**2) - qstar/2/v # - (n/(2+1))*np.log(2*np.pi*v) 
        
        qstar_new = calc_q_star(data, phi_new)
        
        loglike1 = .5*np.log(1-phi_new**2) - qstar_new/2/v # - (n/(2+1))*np.log(2*np.pi*v)
        
        r = np.exp(loglike1-loglike0)
        
        r_list[i]=r
        
        # only accept new phi with probability r
        if r < np.random.rand(): #draw from uniform dist over [0,1]
            rejected +=1
            phi_new = phi_list[i-1]
        else: 
            qstar=qstar_new
            
    else:
        phi_new = phi_list[i-1]
        rejected += 1
        rejected_oob += 1
    
    phi_list[i] = phi_new

print 'iterations = ', iterations
print 'acceptance = ', iterations - rejected
print 'accentance rate = {}'.format(1-rejected/iterations)
print 'out of bounds = ', rejected_oob
# Out:
# iterations =  10000
# acceptance =  3778
# accentance rate = 0.3778
# out of bounds =  0
# CPU times: user 1.61 s, sys: 74.9 ms, total: 1.69 s
# Wall time: 1.8 s

# %%
burn = 0
until = -1 
plt.figure(figsize=(12,8))
plt.subplot(211)
plt.plot(v_list[burn:until]);
plt.title('v');
plt.subplot(212)
plt.plot(phi_list[burn:until]);
plt.title('phi');

# %% [markdown]
# Check Fits

# %%
burn = 100
plt.figure(figsize=(12,4))

plt.subplot(121)

n_bins = 30
fit_t_dist(phi_list[burn:], plot=True)
plt.hist(phi_list[burn:], n_bins, normed=True);
#plt.xlim((0, 3))
plt.title('Phi')

plt.subplot(122)

fit_invgamma_dist(v_list[burn:], True)
plt.hist(v_list[burn:], n_bins, normed=True);
#plt.xlim((1,2))
plt.title("v")

# %% [markdown]
# Check for estimation value

# %%
t_dist = fit_t_dist(phi_list[burn:])
t_dist.mean()
# Out:
# 0.49582149298975514

# %%
phi_real
# Out:
# 0.5

# %%
ig_dist = fit_invgamma_dist(v_list[burn:])
ig_dist.mean()
# Out:
# 0.010066201356559114

# %%
sig_real**2
# Out:
# 0.010000000000000002
